# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['veterinaria']
colecao = db['atendimentos']

# %%
dados = [
{"tutor":"Ana","animal":"Cachorro","nome_pet":"Rex1","servico":"Consulta","valor":120,"cidade":"Assis","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Bruno","animal":"Gato","nome_pet":"Mimi2","servico":"Vacinação","valor":95,"cidade":"Assis","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Carlos","animal":"Cachorro","nome_pet":"Thor3","servico":"Banho","valor":60,"cidade":"Assis","data":datetime(2026,3,3),"forma_pagamento":"Dinheiro"},
{"tutor":"Daniela","animal":"Ave","nome_pet":"Piu4","servico":"Exame","valor":180,"cidade":"Assis","data":datetime(2026,3,4),"forma_pagamento":"Cartão"},
{"tutor":"Eduardo","animal":"Gato","nome_pet":"Luna5","servico":"Consulta","valor":130,"cidade":"Assis","data":datetime(2026,3,5),"forma_pagamento":"Pix"},
{"tutor":"Fernanda","animal":"Cachorro","nome_pet":"Bob6","servico":"Vacinação","valor":90,"cidade":"Assis","data":datetime(2026,3,6),"forma_pagamento":"Dinheiro"},
{"tutor":"Gabriel","animal":"Coelho","nome_pet":"Pompom7","servico":"Consulta","valor":110,"cidade":"Assis","data":datetime(2026,3,7),"forma_pagamento":"Pix"},
{"tutor":"Helena","animal":"Cachorro","nome_pet":"Mel8","servico":"Cirurgia","valor":820,"cidade":"Assis","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Igor","animal":"Gato","nome_pet":"Simba9","servico":"Banho","valor":55,"cidade":"Assis","data":datetime(2026,3,9),"forma_pagamento":"Cartão"},
{"tutor":"Juliana","animal":"Cachorro","nome_pet":"Nina10","servico":"Consulta","valor":125,"cidade":"Assis","data":datetime(2026,3,10),"forma_pagamento":"Pix"},
{"tutor":"Lucas","animal":"Ave","nome_pet":"Sky11","servico":"Exame","valor":200,"cidade":"Assis","data":datetime(2026,3,11),"forma_pagamento":"Cartão"},
{"tutor":"Mariana","animal":"Gato","nome_pet":"Lili12","servico":"Consulta","valor":135,"cidade":"Assis","data":datetime(2026,3,12),"forma_pagamento":"Pix"},
{"tutor":"Nicolas","animal":"Cachorro","nome_pet":"Bolt13","servico":"Vacinação","valor":100,"cidade":"Assis","data":datetime(2026,3,13),"forma_pagamento":"Dinheiro"},
{"tutor":"Patricia","animal":"Cachorro","nome_pet":"Max14","servico":"Consulta","valor":140,"cidade":"Ourinhos","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Rafael","animal":"Gato","nome_pet":"Mia15","servico":"Banho","valor":65,"cidade":"Ourinhos","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Sofia","animal":"Cachorro","nome_pet":"Luna16","servico":"Cirurgia","valor":900,"cidade":"Ourinhos","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Thiago","animal":"Ave","nome_pet":"Blue17","servico":"Exame","valor":170,"cidade":"Ourinhos","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Vanessa","animal":"Gato","nome_pet":"Nino18","servico":"Consulta","valor":125,"cidade":"Ourinhos","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"William","animal":"Cachorro","nome_pet":"Thor19","servico":"Vacinação","valor":95,"cidade":"Ourinhos","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Beatriz","animal":"Coelho","nome_pet":"Fluffy20","servico":"Consulta","valor":115,"cidade":"Ourinhos","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Caio","animal":"Cachorro","nome_pet":"Spike21","servico":"Banho","valor":70,"cidade":"Ourinhos","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Diego","animal":"Gato","nome_pet":"Tom22","servico":"Consulta","valor":135,"cidade":"Ourinhos","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Elisa","animal":"Cachorro","nome_pet":"Mel23","servico":"Exame","valor":210,"cidade":"Ourinhos","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Felipe","animal":"Ave","nome_pet":"Kiwi24","servico":"Consulta","valor":120,"cidade":"Ourinhos","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Gisele","animal":"Gato","nome_pet":"Nina25","servico":"Vacinação","valor":85,"cidade":"Ourinhos","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Hugo","animal":"Cachorro","nome_pet":"Rex26","servico":"Consulta","valor":150,"cidade":"Ourinhos","data":datetime(2026,3,13),"forma_pagamento":"Cartão"},
{"tutor":"Iris","animal":"Cachorro","nome_pet":"Bob27","servico":"Consulta","valor":110,"cidade":"Pompeia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Joao","animal":"Gato","nome_pet":"Luna28","servico":"Banho","valor":60,"cidade":"Pompeia","data":datetime(2026,3,2),"forma_pagamento":"Dinheiro"},
{"tutor":"Karen","animal":"Cachorro","nome_pet":"Thor29","servico":"Cirurgia","valor":780,"cidade":"Pompeia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Leo","animal":"Ave","nome_pet":"Sky30","servico":"Exame","valor":160,"cidade":"Pompeia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Marta","animal":"Gato","nome_pet":"Mimi31","servico":"Consulta","valor":120,"cidade":"Pompeia","data":datetime(2026,3,5),"forma_pagamento":"Cartão"},
{"tutor":"Nelson","animal":"Cachorro","nome_pet":"Max32","servico":"Vacinação","valor":90,"cidade":"Pompeia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Olga","animal":"Coelho","nome_pet":"Pompom33","servico":"Consulta","valor":105,"cidade":"Pompeia","data":datetime(2026,3,7),"forma_pagamento":"Dinheiro"},
{"tutor":"Paulo","animal":"Cachorro","nome_pet":"Bolt34","servico":"Banho","valor":75,"cidade":"Pompeia","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Quezia","animal":"Gato","nome_pet":"Simba35","servico":"Consulta","valor":130,"cidade":"Pompeia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Renato","animal":"Cachorro","nome_pet":"Nina36","servico":"Exame","valor":190,"cidade":"Pompeia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Sara","animal":"Ave","nome_pet":"Blue37","servico":"Consulta","valor":115,"cidade":"Pompeia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Tiago","animal":"Gato","nome_pet":"Lili38","servico":"Vacinação","valor":85,"cidade":"Pompeia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Ursula","animal":"Cachorro","nome_pet":"Rex39","servico":"Consulta","valor":145,"cidade":"Marilia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Vitor","animal":"Gato","nome_pet":"Mia40","servico":"Banho","valor":70,"cidade":"Marilia","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Wesley","animal":"Cachorro","nome_pet":"Thor41","servico":"Cirurgia","valor":870,"cidade":"Marilia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Xuxa","animal":"Ave","nome_pet":"Piu42","servico":"Exame","valor":175,"cidade":"Marilia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Yara","animal":"Gato","nome_pet":"Luna43","servico":"Consulta","valor":135,"cidade":"Marilia","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"Zeca","animal":"Cachorro","nome_pet":"Bob44","servico":"Vacinação","valor":100,"cidade":"Marilia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Aline","animal":"Coelho","nome_pet":"Fluffy45","servico":"Consulta","valor":120,"cidade":"Marilia","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Bruna","animal":"Cachorro","nome_pet":"Spike46","servico":"Banho","valor":80,"cidade":"Marilia","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Cesar","animal":"Gato","nome_pet":"Tom47","servico":"Consulta","valor":140,"cidade":"Marilia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Dora","animal":"Cachorro","nome_pet":"Mel48","servico":"Exame","valor":220,"cidade":"Marilia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Enzo","animal":"Ave","nome_pet":"Kiwi49","servico":"Consulta","valor":130,"cidade":"Marilia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Fabio","animal":"Gato","nome_pet":"Nina50","servico":"Vacinação","valor":90,"cidade":"Marilia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c33c8653f4da3efa491905'), ObjectId('69c33c8653f4da3efa491906'), ObjectId('69c33c8653f4da3efa491907'), ObjectId('69c33c8653f4da3efa491908'), ObjectId('69c33c8653f4da3efa491909'), ObjectId('69c33c8653f4da3efa49190a'), ObjectId('69c33c8653f4da3efa49190b'), ObjectId('69c33c8653f4da3efa49190c'), ObjectId('69c33c8653f4da3efa49190d'), ObjectId('69c33c8653f4da3efa49190e'), ObjectId('69c33c8653f4da3efa49190f'), ObjectId('69c33c8653f4da3efa491910'), ObjectId('69c33c8653f4da3efa491911'), ObjectId('69c33c8653f4da3efa491912'), ObjectId('69c33c8653f4da3efa491913'), ObjectId('69c33c8653f4da3efa491914'), ObjectId('69c33c8653f4da3efa491915'), ObjectId('69c33c8653f4da3efa491916'), ObjectId('69c33c8653f4da3efa491917'), ObjectId('69c33c8653f4da3efa491918'), ObjectId('69c33c8653f4da3efa491919'), ObjectId('69c33c8653f4da3efa49191a'), ObjectId('69c33c8653f4da3efa49191b'), ObjectId('69c33c8653f4da3efa49191c'), ObjectId('69c33c8653f4da3efa49191d'), ObjectId('69c33c8653f4da3efa49191e'), ObjectId('69c33c8653f4da3efa49191f'), ObjectId('69c33c8653f4da3efa491920'), ObjectId('69c33c8653f4da3efa491921'), ObjectId('69c33c8653f4da3efa491922'), ObjectId('69c33c8653f4da3efa491923'), ObjectId('69c33c8653f4da3efa491924'), ObjectId('69c33c8653f4da3efa491925'), ObjectId('69c33c8653f4da3efa491926'), ObjectId('69c33c8653f4da3efa491927'), ObjectId('69c33c8653f4da3efa491928'), ObjectId('69c33c8653f4da3efa491929'), ObjectId('69c33c8653f4da3efa49192a'), ObjectId('69c33c8653f4da3efa49192b'), ObjectId('69c33c8653f4da3efa49192c'), ObjectId('69c33c8653f4da3efa49192d'), ObjectId('69c33c8653f4da3efa49192e'), ObjectId('69c33c8653f4da3efa49192f'), ObjectId('69c33c8653f4da3efa491930'), ObjectId('69c33c8653f4da3efa491931'), ObjectId('69c33c8653f4da3efa491932'), ObjectId('69c33c8653f4da3efa491933'), ObjectId('69c33c8653f4da3efa491934'), ObjectId('69c33c8653f4da3efa491935'), ObjectId('69c33c8653f4da3efa491936')], acknowledged=True)

# %%
dados_mongo = list(colecao.find({
    'valor' : {'$gte': 90, '$lte' : 200}
}))
display(dados_mongo)
# Out:
# [{'_id': ObjectId('69c33435d5003b27fdc09992'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc09993'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc09995'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc09996'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc09997'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc09998'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999b'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999c'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999d'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999e'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999f'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a2'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a3'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a4'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a5'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a7'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a9'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ab'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ac'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099af'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b0'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b1'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b2'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b4'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b5'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b6'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b8'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099bb'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099bc'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099bd'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099be'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099c0'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099c2'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099c3'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d2'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d3'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d5'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d6'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d7'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d8'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918db'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918dc'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918dd'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918de'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918df'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e2'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e3'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e4'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e5'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e7'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e9'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918eb'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ec'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ef'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f0'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f1'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f2'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f4'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f5'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f6'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f8'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918fb'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918fc'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918fd'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918fe'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa491900'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa491902'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa491903'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491905'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491906'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491908'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491909'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190a'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190b'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190e'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190f'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491910'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491911'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491912'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491915'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491916'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491917'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491918'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191a'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191c'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191e'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191f'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491922'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491923'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491924'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491925'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491927'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491928'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491929'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49192b'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49192e'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49192f'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491930'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491931'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491933'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491935'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491936'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %%
dados_cidade = list(colecao.find({
    'cidade' : {'$in' : ['Ourinhos', 'Assis', 'Pompeia', 'Marília']}
}))
display(dados_cidade)
# Out:
# [{'_id': ObjectId('69c33435d5003b27fdc09992'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc09993'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc09994'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc09995'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc09996'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc09997'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc09998'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc09999'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999a'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999b'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999c'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999d'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999e'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc0999f'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a0'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a1'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a2'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a3'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a4'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a5'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a6'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a7'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a8'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099a9'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099aa'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ab'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ac'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ad'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099ae'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099af'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b0'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b1'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b2'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b3'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b4'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b5'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b6'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33435d5003b27fdc099b7'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d2'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d3'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d4'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d5'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d6'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d7'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d8'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918d9'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918da'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918db'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918dc'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918dd'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918de'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918df'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e0'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e1'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e2'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e3'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e4'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e5'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e6'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e7'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e8'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918e9'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ea'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918eb'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ec'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ed'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ee'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918ef'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f0'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f1'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f2'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f3'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f4'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f5'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f6'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8253f4da3efa4918f7'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491905'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491906'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491907'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491908'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491909'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190a'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190b'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190c'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190d'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190e'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49190f'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491910'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491911'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491912'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491913'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491914'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491915'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491916'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491917'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491918'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491919'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191a'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191b'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191c'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191d'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191e'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa49191f'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491920'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491921'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491922'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491923'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491924'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491925'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c33c8653f4da3efa491926'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491927'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa491928'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c33c8653f4da3efa491929'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c33c8653f4da3efa49192a'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %%
df = pd.DataFrame(dados_cidade)
df
# Out:
#                           _id    tutor    animal nome_pet    servico  valor  \
# 0    69c33435d5003b27fdc09992      Ana  Cachorro     Rex1   Consulta    120
# 1    69c33435d5003b27fdc09993    Bruno      Gato    Mimi2  Vacinação     95
# 2    69c33435d5003b27fdc09994   Carlos  Cachorro    Thor3      Banho     60
# 3    69c33435d5003b27fdc09995  Daniela       Ave     Piu4      Exame    180
# 4    69c33435d5003b27fdc09996  Eduardo      Gato    Luna5   Consulta    130
# ..                        ...      ...       ...      ...        ...    ...
# 109  69c33c8653f4da3efa491926    Paulo  Cachorro   Bolt34      Banho     75
# 110  69c33c8653f4da3efa491927   Quezia      Gato  Simba35   Consulta    130
# 111  69c33c8653f4da3efa491928   Renato  Cachorro   Nina36      Exame    190
# 112  69c33c8653f4da3efa491929     Sara       Ave   Blue37   Consulta    115
# 113  69c33c8653f4da3efa49192a    Tiago      Gato   Lili38  Vacinação     85
#
#       cidade       data forma_pagamento
# 0      Assis 2026-03-01             Pix
# 1      Assis 2026-03-02          Cartão
# 2      Assis 2026-03-03        Dinheiro
# 3      Assis 2026-03-04          Cartão
# 4      Assis 2026-03-05             Pix
# ..       ...        ...             ...
# 109  Pompeia 2026-03-08          Cartão
# 110  Pompeia 2026-03-09             Pix
# 111  Pompeia 2026-03-10          Cartão
# 112  Pompeia 2026-03-11             Pix
# 113  Pompeia 2026-03-12        Dinheiro
#
# [114 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# _id                0
# tutor              0
# animal             0
# nome_pet           0
# servico            0
# valor              0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
faturamento = df['valor'].sum()
print("Faturamento Total: ", faturamento)
# Out:
# Faturamento Total:  13240

# %%
faturamento_produto = df.groupby('cidade')['valor'].sum().sort_values(ascending=False)
faturamento_produto
# Out:
# cidade
# Ourinhos    4760
# Assis       4440
# Pompeia     4040
# Name: valor, dtype: int64

# %%
faturamento_servico = df.groupby('servico')['valor'].sum().sort_values(ascending=False)
faturamento_servico
# Out:
# servico
# Cirurgia     5000
# Consulta     3970
# Exame        2220
# Vacinação    1280
# Banho         770
# Name: valor, dtype: int64

# %%
ticket = df['valor'].mean()
print(f"Média do valor das Vendas: {ticket:.2f}")
# Out:
# Média do valor das Vendas: 174.21

# %%
ticket_medio_por_cidade = df.groupby('cidade')['valor'].mean().sort_values(ascending=False)
ticket_medio_por_cidade
# Out:
# cidade
# Ourinhos    183.076923
# Assis       170.769231
# Pompeia     168.333333
# Name: valor, dtype: float64

# %%
servico_mais_lucrativo = df.groupby('servico')['valor'].sum().idxmax()
servico_mais_lucrativo
# Out:
# 'Cirurgia'

# %%
cidade_com_maior_faturamento = df['cidade'].value_counts().idxmax()
cidade_com_maior_faturamento
# Out:
# 'Assis'

# %%
top_3_atendimentos = df['servico'].value_counts().head(3)
print("Top 3 atendimentos com mais atendimentos:")
print(top_3_atendimentos)
# Out:
# Top 3 atendimentos com mais atendimentos:
# servico
# Consulta     32
# Vacinação    14
# Banho        12
# Name: count, dtype: int64

# %%
# Gerar relatório
relatorio = {
    'data_geracao': datetime.now(),
    'faturamento_total': float(faturamento),
    'faturamento_por_cidade': faturamento_servico.to_dict(), 
    'faturamento_por_servico': df.groupby('servico')['valor'].sum().to_dict(),
    'ticket_medio_geral': float(ticket),
    'ticket_medio_por_cidade': ticket_medio_por_cidade.to_dict(),
    'servico_mais_lucrativo': servico_mais_lucrativo,
    'cidade_maior_faturamento': cidade_com_maior_faturamento,
    'top_3_atendimentos': df.nlargest(3, 'valor').to_dict('records')
}
print("Relatório gerado e salvo com sucesso")
print(relatorio)
# Out:
# Relatório gerado e salvo com sucesso
# {'data_geracao': datetime.datetime(2026, 3, 25, 1, 38, 21, 394093), 'faturamento_total': 13240.0, 'faturamento_por_cidade': {'Cirurgia': 5000, 'Consulta': 3970, 'Exame': 2220, 'Vacinação': 1280, 'Banho': 770}, 'faturamento_por_servico': {'Banho': 1155, 'Cirurgia': 7500, 'Consulta': 5955, 'Exame': 3330, 'Vacinação': 1920}, 'ticket_medio_geral': 174.21052631578948, 'ticket_medio_por_cidade': {'Ourinhos': 183.07692307692307, 'Assis': 170.76923076923077, 'Pompeia': 168.33333333333334}, 'servico_mais_lucrativo': 'Cirurgia', 'cidade_maior_faturamento': 'Assis', 'top_3_atendimentos': [{'_id': ObjectId('69c33435d5003b27fdc099a1'), 'tutor': 'Sofia', 'animal': 'Cachorro', 'nome_pet': 'Luna16', 'servico': 'Cirurgia', 'valor': 900, 'cidade': 'Ourinhos', 'data': Timestamp('2026-03-03 00:00:00'), 'forma_pagamento': 'Cartão'}, {'_id': ObjectId('69c33c8253f4da3efa4918e1'), 'tutor': 'Sofia', 'animal': 'Cachorro', 'nome_pet': 'Luna16', 'servico': 'Cirurgia', 'valor': 900, 'cidade': 'Ourinhos', 'data': Timestamp('2026-03-03 00:00:00'), 'forma_pagamento': 'Cartão'}, {'_id': ObjectId('69c33c8653f4da3efa491914'), 'tutor': 'Sofia', 'animal': 'Cachorro', 'nome_pet': 'Luna16', 'servico': 'Cirurgia', 'valor': 900, 'cidade': 'Ourinhos', 'data': Timestamp('2026-03-03 00:00:00'), 'forma_pagamento': 'Cartão'}]}
