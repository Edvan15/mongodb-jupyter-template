# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['loja']
colecao = db['vendas']

# %%
dados = [
    {
        "cliente": "Ana",
        "produto": "Mouse",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 50,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 1),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Bruno",
        "produto": "Teclado",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 120,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Carla",
        "produto": "Caderno",
        "categoria": "Papelaria",
        "quantidade": 5,
        "preco_unitario": 15,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "Daniel",
        "produto": "Caneta",
        "categoria": "Papelaria",
        "quantidade": 10,
        "preco_unitario": 3,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Elaine",
        "produto": "Monitor",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 900,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Fabio",
        "produto": "Mochila",
        "categoria": "Acessórios",
        "quantidade": 2,
        "preco_unitario": 80,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Boleto"
    },
    {
        "cliente": "Gabriela",
        "produto": "Livro",
        "categoria": "Livros",
        "quantidade": 3,
        "preco_unitario": 40,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Henrique",
        "produto": "Fone",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 150,
        "cidade": "Assis",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Isabela",
        "produto": "Agenda",
        "categoria": "Papelaria",
        "quantidade": 4,
        "preco_unitario": 20,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "João",
        "produto": "Webcam",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 250,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 6),
        "forma_pagamento": "Pix"
    }
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c32de66d98bec8c90c4d0d'), ObjectId('69c32de66d98bec8c90c4d0e'), ObjectId('69c32de66d98bec8c90c4d0f'), ObjectId('69c32de66d98bec8c90c4d10'), ObjectId('69c32de66d98bec8c90c4d11'), ObjectId('69c32de66d98bec8c90c4d12'), ObjectId('69c32de66d98bec8c90c4d13'), ObjectId('69c32de66d98bec8c90c4d14'), ObjectId('69c32de66d98bec8c90c4d15'), ObjectId('69c32de66d98bec8c90c4d16')], acknowledged=True)

# %%
dados_exemplo = list(colecao.find({'cliente' : 'Bruno'}))
display(dados_exemplo)
# Out:
# [{'_id': ObjectId('69c3185ab0d1ffad92b1e8c1'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8cb'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c321b215a1b201a860e86c'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32d8f0455196974629568'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d0e'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_mongo = list(colecao.find({
    'preco_unitario' : {'$gte': 100, '$lte' : 300}
}))
display(dados_mongo)
# Out:
# [{'_id': ObjectId('69c3185ab0d1ffad92b1e8c1'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c7'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c9'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8cb'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8d1'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8d3'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c321b215a1b201a860e86c'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c321b215a1b201a860e872'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c321b215a1b201a860e874'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32d8f0455196974629568'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32d8f045519697462956e'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32d8f0455196974629570'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d0e'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d14'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d16'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_cidade = list(colecao.find({
    'cidade' : {'$in' : ['Ourinhos', 'Assis']}
}))
display(dados_cidade)
# Out:
# [{'_id': ObjectId('69c3185ab0d1ffad92b1e8c0'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c2'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c4'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c6'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c7'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3185ab0d1ffad92b1e8c9'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8ca'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8cc'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8ce'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8d0'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8d1'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c319bcb0d1ffad92b1e8d3'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c321b215a1b201a860e86b'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c321b215a1b201a860e86d'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c321b215a1b201a860e86f'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c321b215a1b201a860e871'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c321b215a1b201a860e872'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c321b215a1b201a860e874'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32d8f0455196974629567'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32d8f0455196974629569'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c32d8f045519697462956b'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32d8f045519697462956d'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32d8f045519697462956e'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32d8f0455196974629570'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d0d'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d0f'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d11'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d13'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d14'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c32de66d98bec8c90c4d16'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
df = pd.DataFrame(dados_cidade)
df
# Out:
#                          _id   cliente  produto    categoria  quantidade  \
# 0   69c3185ab0d1ffad92b1e8c0       Ana    Mouse  Informática           2
# 1   69c3185ab0d1ffad92b1e8c2     Carla  Caderno    Papelaria           5
# 2   69c3185ab0d1ffad92b1e8c4    Elaine  Monitor  Informática           1
# 3   69c3185ab0d1ffad92b1e8c6  Gabriela    Livro       Livros           3
# 4   69c3185ab0d1ffad92b1e8c7  Henrique     Fone  Informática           2
# 5   69c3185ab0d1ffad92b1e8c9      João   Webcam  Informática           1
# 6   69c319bcb0d1ffad92b1e8ca       Ana    Mouse  Informática           2
# 7   69c319bcb0d1ffad92b1e8cc     Carla  Caderno    Papelaria           5
# 8   69c319bcb0d1ffad92b1e8ce    Elaine  Monitor  Informática           1
# 9   69c319bcb0d1ffad92b1e8d0  Gabriela    Livro       Livros           3
# 10  69c319bcb0d1ffad92b1e8d1  Henrique     Fone  Informática           2
# 11  69c319bcb0d1ffad92b1e8d3      João   Webcam  Informática           1
# 12  69c321b215a1b201a860e86b       Ana    Mouse  Informática           2
# 13  69c321b215a1b201a860e86d     Carla  Caderno    Papelaria           5
# 14  69c321b215a1b201a860e86f    Elaine  Monitor  Informática           1
# 15  69c321b215a1b201a860e871  Gabriela    Livro       Livros           3
# 16  69c321b215a1b201a860e872  Henrique     Fone  Informática           2
# 17  69c321b215a1b201a860e874      João   Webcam  Informática           1
# 18  69c32d8f0455196974629567       Ana    Mouse  Informática           2
# 19  69c32d8f0455196974629569     Carla  Caderno    Papelaria           5
# 20  69c32d8f045519697462956b    Elaine  Monitor  Informática           1
# 21  69c32d8f045519697462956d  Gabriela    Livro       Livros           3
# 22  69c32d8f045519697462956e  Henrique     Fone  Informática           2
# 23  69c32d8f0455196974629570      João   Webcam  Informática           1
# 24  69c32de66d98bec8c90c4d0d       Ana    Mouse  Informática           2
# 25  69c32de66d98bec8c90c4d0f     Carla  Caderno    Papelaria           5
# 26  69c32de66d98bec8c90c4d11    Elaine  Monitor  Informática           1
# 27  69c32de66d98bec8c90c4d13  Gabriela    Livro       Livros           3
# 28  69c32de66d98bec8c90c4d14  Henrique     Fone  Informática           2
# 29  69c32de66d98bec8c90c4d16      João   Webcam  Informática           1
#
#     preco_unitario    cidade       data forma_pagamento
# 0               50  Ourinhos 2026-03-01          Cartão
# 1               15  Ourinhos 2026-03-02        Dinheiro
# 2              900  Ourinhos 2026-03-03          Cartão
# 3               40  Ourinhos 2026-03-04             Pix
# 4              150     Assis 2026-03-05          Cartão
# 5              250  Ourinhos 2026-03-06             Pix
# 6               50  Ourinhos 2026-03-01          Cartão
# 7               15  Ourinhos 2026-03-02        Dinheiro
# 8              900  Ourinhos 2026-03-03          Cartão
# 9               40  Ourinhos 2026-03-04             Pix
# 10             150     Assis 2026-03-05          Cartão
# 11             250  Ourinhos 2026-03-06             Pix
# 12              50  Ourinhos 2026-03-01          Cartão
# 13              15  Ourinhos 2026-03-02        Dinheiro
# 14             900  Ourinhos 2026-03-03          Cartão
# 15              40  Ourinhos 2026-03-04             Pix
# 16             150     Assis 2026-03-05          Cartão
# 17             250  Ourinhos 2026-03-06             Pix
# 18              50  Ourinhos 2026-03-01          Cartão
# 19              15  Ourinhos 2026-03-02        Dinheiro
# 20             900  Ourinhos 2026-03-03          Cartão
# 21              40  Ourinhos 2026-03-04             Pix
# 22             150     Assis 2026-03-05          Cartão
# 23             250  Ourinhos 2026-03-06             Pix
# 24              50  Ourinhos 2026-03-01          Cartão
# 25              15  Ourinhos 2026-03-02        Dinheiro
# 26             900  Ourinhos 2026-03-03          Cartão
# 27              40  Ourinhos 2026-03-04             Pix
# 28             150     Assis 2026-03-05          Cartão
# 29             250  Ourinhos 2026-03-06             Pix

# %%
df.isnull().sum()
# Out:
# _id                0
# cliente            0
# produto            0
# categoria          0
# quantidade         0
# preco_unitario     0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %%
df['valor_total'] = df['quantidade'] * df['preco_unitario']
df.head(5)
# Out:
#                         _id   cliente  produto    categoria  quantidade  \
# 0  69c3185ab0d1ffad92b1e8c0       Ana    Mouse  Informática           2
# 1  69c3185ab0d1ffad92b1e8c2     Carla  Caderno    Papelaria           5
# 2  69c3185ab0d1ffad92b1e8c4    Elaine  Monitor  Informática           1
# 3  69c3185ab0d1ffad92b1e8c6  Gabriela    Livro       Livros           3
# 4  69c3185ab0d1ffad92b1e8c7  Henrique     Fone  Informática           2
#
#    preco_unitario    cidade       data forma_pagamento  valor_total
# 0              50  Ourinhos 2026-03-01          Cartão          100
# 1              15  Ourinhos 2026-03-02        Dinheiro           75
# 2             900  Ourinhos 2026-03-03          Cartão          900
# 3              40  Ourinhos 2026-03-04             Pix          120
# 4             150     Assis 2026-03-05          Cartão          300

# %%
faturamento = df['valor_total'].sum()
print("Faturamento Total: ", faturamento)
# Out:
# Faturamento Total:  8725

# %%
faturamento_categoria = df.groupby('categoria')['valor_total'].sum().sort_values(ascending=False)
faturamento_categoria
# Out:
# categoria
# Informática    7750
# Livros          600
# Papelaria       375
# Name: valor_total, dtype: int64

# %%
#pergunta de prova
faturamento_produto = df.groupby('produto')['valor_total'].sum().sort_values(ascending=False)
faturamento_produto
# Out:
# produto
# Monitor    4500
# Fone       1500
# Webcam     1250
# Livro       600
# Mouse       500
# Caderno     375
# Name: valor_total, dtype: int64

# %%
vendas_por_cidade = df['cidade'].value_counts()
vendas_por_cidade
# Out:
# cidade
# Ourinhos    25
# Assis        5
# Name: count, dtype: int64

# %%
media_valor_vendas = df['valor_total'].mean()
print(f"Média do valor das Vendas: {media_valor_vendas:.2f}")
# Out:
# Média do valor das Vendas: 290.83

# %%
produto_top = df.groupby('produto')['valor_total'].sum().idxmax()
produto_top
# Out:
# 'Monitor'

# %%
cidade_top = df['cidade'].value_counts().idxmax()
cidade_top
# Out:
# 'Ourinhos'

# %%
relatorio = {
    'data_geracao' : datetime.now(),
    'faturamento_total' : float(faturamento),
    'faturamento_categoria' : faturamento_categoria.to_dict(),
    'produto_top' : produto_top,
    'cidade_top' : cidade_top
}
display(relatorio)
# Out:
# {'data_geracao': datetime.datetime(2026, 3, 25, 0, 38, 49, 965881),
#  'faturamento_total': 8725.0,
#  'faturamento_categoria': {'Informática': 7750,
#   'Livros': 600,
#   'Papelaria': 375},
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}

# %%
colecao_relatorios = db['relatorio']
colecao_relatorios.insert_one(relatorio)
# Out:
# InsertOneResult(ObjectId('69c32ec76d98bec8c90c4d17'), acknowledged=True)

# %%
for r in colecao_relatorios.find(): 
    display(r)
# Out:
# {'_id': ObjectId('69c32ec76d98bec8c90c4d17'),
#  'data_geracao': datetime.datetime(2026, 3, 25, 0, 38, 49, 965000),
#  'faturamento_total': 8725.0,
#  'faturamento_categoria': {'Informática': 7750,
#   'Livros': 600,
#   'Papelaria': 375},
#  'produto_top': 'Monitor',
#  'cidade_top': 'Ourinhos'}
